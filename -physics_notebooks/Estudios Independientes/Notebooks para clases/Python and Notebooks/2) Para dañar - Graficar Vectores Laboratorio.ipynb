# %%
import matplotlib.pyplot as plt
import numpy as np
from pathlib import Path
import math as m
from matplotlib.font_manager import FontProperties
from scipy.optimize import curve_fit

#from sympy import init_session
#init_session()
font = FontProperties()
font.set_family('dejavusans')
font.set_name('dejavusans')
#font.set_style('italic')
font.set_size(13)

# %%
X_0 = np.array([
#0,
#5,
#10,
#20,
#40,
#60,
#80,
#85 
0,
5,
10,
20,
35,
40,
45,
60,
70      
#0,
#20,
#40,
#60,
#70,
#75   
#0,
#10,
#20,
#30,
#35,
#37,
#39,
#43,
#45,
#50,
#55,
#70,
#75
]);


Y_0 = np.array([
6.87,
6.85,
6.84,
6.86,
6.85,
6.84,
6.83,
6.81,
6.87,
6.85,
6.86,
6.82,
6.84
]);

#X_0 = np.sin((X_00*np.pi)/180)
#Y_0 = np.sin((Y_00*np.pi)/180)

#X_1 = np.array([
#0,
#9,
#13,
#18,
#23,
#33,
#39
#]);

Y_1 = np.array([
np.nan,
0.134,
0.131, 
0.104,
0.0752,
0.0805,
0.109,
0.800,
3.35
]);



def fun(x, m, b):
    return x*m + b

#coef00, cov00 = curve_fit(fun, X_0, Y_0)
#coef11, cov11 = curve_fit(fun, X_1, Y_1)
#coef12, cov12 = curve_fit(fun_exp, X_1, Y_2)
#coef13, cov13 = curve_fit(fun_exp, X_1, Y_3)
#coef24, cov24 = curve_fit(fun_exp, X_2, Y_4)
#coef25, cov25 = curve_fit(fun_exp, X_2, Y_5)

#f_0 = np.polyfit(X_0,Y_0, 3)
#f_1 = np.polyfit(X_0,Y_1, 3)
#f_2 = np.polyfit(X_0,Y_2, 1)

#f_1 = np.polyfit(X_1,Y_1, 1)
#f_2 = np.polyfit(X_2,Y_2, 1)

#p0 = np.poly1d(f_0)
#p1 = np.poly1d(f_1)
#p2 = np.poly1d(f_2)

#p1 = np.poly1d(f_1)
#p2 = np.poly1d(f_2)

#xp0 = np.linspace(np.min(X_0), np.max(X_0), 200)
#xp1 = np.linspace(np.min(X_0), np.max(X_0), 200)
#xp2 = np.linspace(np.min(X_2), np.max(X_2), 200)
#xp00 = np.linspace(0, np.min(X_0), 200) esto es para extrapolar el modelo


#xp1 = np.linspace(np.min(X_1), np.max(X_1), 200)
#xp2 = np.linspace(np.min(X_2), np.max(X_2), 200)

# %%
fig, ax = plt.subplots()


#ax.plot(X_0,Y_0,'+')
#ax.plot(X_0,Y_0,'--')
ax.plot(X_0, Y_1, "o")
#ax.plot(X_0, Y_1, "--")

#ax.plot(X_0, Y_0 + Y_1, '--')
#ax.plot(X_0,Y_0,'o', xp1, fun(xp1, coef00[0], coef00[1]))
#ax.plot(xp00, p0(xp00), '--') para extrapolar el modelo

#ax.plot(X_0,Y_1,'o', xp0, fun_exp(xp0, coef01[0], coef01[1], coef01[2]))
#ax.plot(xp00, p1(xp00), '--')

#ax.plot(X_0,Y_2,'o', xp0, p2(xp0))
#ax.plot(xp00, p2(xp00), '--')

#ax.legend((r'Iluminancia$_{\parallel}$ Incidente',
#ax.legend(r'Iluminancia$_{\parallel}$ Reflejada')
ax.legend((r'Iluminancia$_{\parallel}$ Reflejada',))
#plt.plot(X_1,Y_1,'o', xp1, p1(xp1))
#plt.plot(X_2,Y_2,'o', xp2, p2(xp2))

#plt.plot(X_0,Y_0,'o')
#plt.plot(X_1,Y_1,'o')
#plt.plot(X_2,Y_2,'o')

#plt.plot(X_0,Y_0)
#plt.plot(X_1,Y_1)
#plt.plot(X_2,Y_2)



#plt.axhline(color="grey")
#plt.axvline(color="grey")

#plt.ylim([-5,45])
#plt.xlim([-5,90])
#plt.legend()

plt.xlabel(r'Àngulo de Incidencia $\theta_i$', fontproperties=font)
plt.ylabel(r'Iluminancia $(klux)$', fontproperties=font)
plt.title(r'Iluminancia$_{\parallel}$ (aire $\rightarrow$ vidrio)', fontsize=15, math_fontfamily='dejavusans')
 
#plt.text(-0.5e+15, -2, r'$-\Phi_{Na} / e^-$', fontsize=14, math_fontfamily='dejavusans')
#plt.text(-0.5e+15, -3, r'$-\Phi_{Ca} / e^-$', fontsize=14, math_fontfamily='dejavusans')
#plt.text(-0.5e+15, -4, r'$-\Phi_{Mg} / e^-$', fontsize=14, math_fontfamily='dejavusans')

#plt.text(3, 43, r'$\theta_2$', fontsize=18, math_fontfamily='cm')
#plt.text(3, 34, r'$\theta_1$', fontsize=18, math_fontfamily='cm')
#plt.text(-4, 11, r'$\lambda_0>\lambda_1>\lambda_2$', fontsize=18, math_fontfamily='cm')

#ax.annotate('Magnesio', xy=(1.5e+15, 2), xytext=(1.8e+15, 2),
#arrowprops=dict(facecolor='grey', shrink=0.001),
#)

#ax.annotate('Calcio', xy=(1.5e+15, 2.9), xytext=(1.8e+15, 2.9),
#arrowprops=dict(facecolor='grey', shrink=0.001),
#)

#ax.annotate('Sodio', xy=(1.5e+15, 3.8), xytext=(1.8e+15, 3.8),
#arrowprops=dict(facecolor='grey', shrink=0.001),
#)


plt.savefig('line_plot2.pdf')
plt.show()

# %%
1/coef00[0]

# %%
coef00[1]

# %%
#indice de refraccion del agua: 1.33
