# %% [markdown]
# ### Cálculo de Control $\xi(t)$ para Sistema de 2 niveles Mediante redes neuronales PINN

# %% [markdown]
# <center>
# <img src="2levelsystem.png" width=200ox>
# </center>
# $\newcommand{\ket}[1]{\left|{#1}\right\rangle}$
# $\newcommand{\bra}[1]{\left\langle{#1}\right|}$
# $\newcommand{\braket}[2]{\left\langle{#1}\middle|{#2}\right\rangle}$

# %% [markdown]
# El hamiltoniano de mi sistema está dado por:
# \begin{equation}
#     H(t) = \omega_z \sigma_z + \omega_x \sigma_x + \xi(t)\sigma_{ee} \quad (1)
# \end{equation}
# con $\omega_{x,z}$ los parámetros del sistema y $\xi(t)$ la función que describe el campo de control desconocido. Además, $\sigma_z = \ket{e}\bra{e}-\ket{g}\bra{g}$, siendo $\ket{e}$ el estado excitado y $\ket{g}$ el estado fundamental.
#
# Con ésto en mente, la dinámica abierta del sistema queda descrita por la ecuación maestra de Markov:
# $$\dot{\rho} = -i[H(t), \rho]+ \sum_{i=1,2} \gamma_i(L_i \rho L_i^{\dagger}-(1/2)\{L_i^{\dagger}L_i,\rho\}) \quad (2)$$
#
# En éste caso particular, la disipación se describe por los procesos de absorción ($L_1 = \ket{e}\bra{g}$) y emisión ($L_2 = \ket{g}\bra{e}$) con tasas de $$\gamma_1 = \gamma_{abs} = 0.1$$ $$\gamma_2 = \gamma_{em} = 0.3$$ Además, se configuran los parámetros del sistema $$\omega_z = 2$$ $$\omega_x = 1$$ y la condición inicial $$\xi(0) = 0$$
#
# > **Objetivo:** Predecir la función del campo de control $\xi(t)$ óptima que nos permita controlar la dinámica de nuestro sistema, para conducirlo desde un estado inicial a otro estado estacionario de la forma: $\rho_d = (1/2)(\ket{e}\bra{e}+\ket{g}\bra{g})$.

# %% [markdown]
# ## Parametrización del problema

# %% [markdown]
# La ecuación de la dinámica de nuestro sistema (2) puede ser reescrita como una ecuación diferencial lineal de la forma:
# $$\frac{dx}{dt} = A(\lambda, u(t))*\mathbf{x}(t) \quad (3)$$ donde $\mathbf{x}(t)$ es un vector real, $\lambda = (\omega_x, \omega_z, \gamma_{abs}, \gamma_{em})$ son los parámetros conocidos del sistema, $\mathbf{u}(t) = \xi(t)$ es el vector unidimensional de control que se quiere hallar.

# %% [markdown]
# Para llegar a ésta forma de matrices, debemos escribir la ecuación (2) en términos de matrices:
#
#     1. Partimos definiendo la matriz densidad correspondiente que representa dicho estado de tamaño 2x2:
#
# $$\rho = \begin{pmatrix} \rho_{11} & Re(\rho_{12})+Im(\rho_{12}) \\
#                         Re(\rho_{21})-Im(\rho_{21}) & \rho_{22}
# \end{pmatrix} = \begin{pmatrix} z_{11} & z_{12r}+z_{12i} \\
#                         z_{21r}-z_{21i} & z_{22}
# \end{pmatrix} = \rho_{Real} + \rho_{Im}$$
#
#     En tal caso:
#
# $$\rho_{Real} = \begin{pmatrix} \rho_{11} & Re(\rho_{12}) \\
#                         Re(\rho_{21}) & \rho_{22}
# \end{pmatrix}$$
#
#
# $$\rho_{Im} = \begin{pmatrix} 0 & Im(\rho_{12}) \\
#                         -Im(\rho_{21}) & 0
# \end{pmatrix}$$

# %%
# %%capture
from sympy import init_session
from IPython.display import display, Math
init_session()
ket_g = Matrix([[1],[0]])
ket_e = Matrix([[0],[1]])

# %%
z1,z2,z12r,z12i  = symbols('z1,z2,z12_r,z12_i',real=True)
rho = Matrix([[z1,z12r+I*z12i],
              [z12r-I*z12i,z2]])
Math(r'\rho'+' = '+latex(rho))
# Out:
# $\displaystyle \rho = \left[\begin{matrix}z_{1} & i z_{12 i} + z_{12 r}\\- i z_{12 i} + z_{12 r} & z_{2}\end{matrix}\right]$

# %% [markdown]
#     2. Seguidamente, se escribe el hamiltoniano en términos de matrices:

# %%
from sympy.physics.matrices import msigma
sigma_z = msigma(3)
#sigma_z = ket_e*ket_e.T - ket_g*ket_g.T
sigma_x = msigma(1)
sigma_ee = ket_e*ket_e.T
omega_z, omega_x, xi = symbols('omega_z omega_x xi', real=True)
xi = symbols('xi', real=True)

# %%
#H = -omega_z*sigma_z + omega_x*sigma_x + xi*sigma_ee
H = -omega_z*sigma_z + omega_x*sigma_x 
Math(r'H = '+ latex(H))
# Out:
# $\displaystyle H = \left[\begin{matrix}- \omega_{z} & \omega_{x}\\\omega_{x} & \omega_{z}\end{matrix}\right]$

# %% [markdown]
#     3. También definimos los términos de disipación:

# %%
gamma_1, gamma_2 = symbols('gamma_abs gamma_em', real=True)
L1 = ket_e*ket_g.T
L2 = ket_g*ket_e.T
disip_1 = gamma_1*((L1*rho*L1.T) - (Rational(1/2)*(L1.T*L1*rho + rho*L1.T*L1)) )
disip_2 = gamma_2*((L2*rho*L2.T) - (Rational(1/2)*(L2.T*L2*rho + rho*L2.T*L2)) )

# %%
disip_1, disip_2, L1, L2
# Out:
# ⎛⎡                               ⎛  ⅈ⋅z₁₂ ᵢ   z₁₂ ᵣ⎞⎤  ⎡
# ⎜⎢       -γ_abs⋅z₁         γ_abs⋅⎜- ─────── - ─────⎟⎥  ⎢       γₑₘ⋅z₂
# ⎜⎢                               ⎝     2        2  ⎠⎥  ⎢
# ⎜⎢                                                  ⎥, ⎢
# ⎜⎢      ⎛ⅈ⋅z₁₂ ᵢ   z₁₂ ᵣ⎞                           ⎥  ⎢    ⎛ⅈ⋅z₁₂ ᵢ   z₁₂ ᵣ⎞
# ⎜⎢γ_abs⋅⎜─────── - ─────⎟          γ_abs⋅z₁         ⎥  ⎢γₑₘ⋅⎜─────── - ─────⎟
# ⎝⎣      ⎝   2        2  ⎠                           ⎦  ⎣    ⎝   2        2  ⎠
#
#      ⎛  ⅈ⋅z₁₂ ᵢ   z₁₂ ᵣ⎞⎤                ⎞
#  γₑₘ⋅⎜- ─────── - ─────⎟⎥                ⎟
#      ⎝     2        2  ⎠⎥  ⎡0  0⎤  ⎡0  1⎤⎟
#                         ⎥, ⎢    ⎥, ⎢    ⎥⎟
#                         ⎥  ⎣1  0⎦  ⎣0  0⎦⎟
#          -γₑₘ⋅z₂        ⎥                ⎟
#                         ⎦                ⎠

# %% [markdown]
#     4. Finalmente obtenemos la ecuación maestra en forma de matriz:

# %%
dot_rho = -I*(H*rho - rho*H) + disip_1 + disip_2
Math(r'\dot{\rho} = '+ latex(expand(dot_rho)))
# Out:
# $\displaystyle \dot{\rho} = \left[\begin{matrix}- \gamma_{abs} z_{1} + \gamma_{em} z_{2} - 2 \omega_{x} z_{12 i} & - \frac{i \gamma_{abs} z_{12 i}}{2} - \frac{\gamma_{abs} z_{12 r}}{2} - \frac{i \gamma_{em} z_{12 i}}{2} - \frac{\gamma_{em} z_{12 r}}{2} + i \omega_{x} z_{1} - i \omega_{x} z_{2} - 2 \omega_{z} z_{12 i} + 2 i \omega_{z} z_{12 r}\\\frac{i \gamma_{abs} z_{12 i}}{2} - \frac{\gamma_{abs} z_{12 r}}{2} + \frac{i \gamma_{em} z_{12 i}}{2} - \frac{\gamma_{em} z_{12 r}}{2} - i \omega_{x} z_{1} + i \omega_{x} z_{2} - 2 \omega_{z} z_{12 i} - 2 i \omega_{z} z_{12 r} & \gamma_{abs} z_{1} - \gamma_{em} z_{2} + 2 \omega_{x} z_{12 i}\end{matrix}\right]$

# %% [markdown]
# Al describir la matriz $\dot{\rho}$ En términos de la ecuación $\dot{x}=\mathbf{A}\mathbf{x}$, considerando a $\mathbf{x} = (\rho_{11},\rho_{22},Re(\rho_{12}),Im(\rho_{12}))^{T}$

# %%
display(Math(r'\dot{x}_1 = '+latex(simplify(dot_rho[0,0]))))
display(Math(r'\dot{x}_2 = '+latex(simplify(dot_rho[1,1]))))
display(Math(r'\dot{x}_3 = '+latex(simplify(re(dot_rho[0,1])))))
display(Math(r'\dot{x}_4 = '+latex(simplify(im(dot_rho[0,1])))))
# Out:
# $\displaystyle \dot{x}_1 = - \gamma_{abs} z_{1} + \gamma_{em} z_{2} - 2 \omega_{x} z_{12 i}$
# $\displaystyle \dot{x}_2 = \gamma_{abs} z_{1} - \gamma_{em} z_{2} + 2 \omega_{x} z_{12 i}$
# $\displaystyle \dot{x}_3 = - \frac{\gamma_{abs} z_{12 r}}{2} - \frac{\gamma_{em} z_{12 r}}{2} - 2 \omega_{z} z_{12 i}$
# $\displaystyle \dot{x}_4 = - \frac{\gamma_{abs} z_{12 i}}{2} - \frac{\gamma_{em} z_{12 i}}{2} + \omega_{x} z_{1} - \omega_{x} z_{2} + 2 \omega_{z} z_{12 r}$

# %% [markdown]
# es decir,

# %% [markdown]
# $$\dot{x} = \begin{pmatrix} -\gamma_{abs} & \gamma_{em} & 0 & -2\omega_x \\  \gamma_{abs} & -\gamma_{em} & 0 & 2\omega_x\\ 0 & 0 & -\Gamma & -2\omega_z - \xi(t) \\ \omega_x & -\omega_x & 2\omega_z + \xi(t) & -\Gamma\end{pmatrix}\begin{pmatrix}\rho_{11} \\ \rho_{22} \\ Re(\rho_{12}) \\ Im(\rho_{12}))\end{pmatrix}$$ siendo $\Gamma = (1/2)(\gamma_1+\gamma_2)$ la tasa de desfase efectiva.

# %%
#Elementos de la diagonal
f1 = f'df(z1,t) + {-simplify(dot_rho[0,0])}'
f2 = f'df(z2,t) {-simplify(dot_rho[1,1])}'
#Parte Real de los elementos
f3 = f'df(z12r,t) + {-re(simplify(dot_rho[0,1]))}'
#Parte Imaginaria de los elementos
f4 = f'df(z12i,t) + {-im(simplify(dot_rho[0,1]))}'

# %%
#Imprimimos en formato de línea las ecuaciones de la dinámica
print(f1+"\n")
print(f2+"\n")
print(f3+"\n")
print(f4+"\n")
# Out:
# df(z1,t) + gamma_abs*z1 - gamma_em*z2 + 2*omega_x*z12_i
#
# df(z2,t) -gamma_abs*z1 + gamma_em*z2 - 2*omega_x*z12_i
#
# df(z12r,t) + gamma_abs*z12_r/2 + gamma_em*z12_r/2 + 2*omega_z*z12_i
#
# df(z12i,t) + gamma_abs*z12_i/2 + gamma_em*z12_i/2 - omega_x*z1 + omega_x*z2 - 2*omega_z*z12_r

# %%
# %reset -f

# %% [markdown]
# # Red Neuronal informada por la física (PINN)

# %% [markdown]
# Importamos el marco de trabajo Pythorch para trabajar nuestra red neuronal de forma dinámica:

# %%
import numpy as np
import torch #Marco de trabajo para redes neuronales
from torch import nn #Herramientas para elaborar el modelo de red neuronal
import matplotlib.pyplot as plt
from torch.autograd import grad

dtype=torch.float

#Se establece el hardware para usar en cálculos de la red neuronal 
device = (
    "cuda"
    if torch.cuda.is_available()
    else "mps"
    if torch.backends.mps.is_available()
    else "cpu"
)
print(f"Usando {device} como plataforma")
# Out:
# Usando cpu como plataforma

# %% [markdown]
# ### Función de activación Sin()

# %% [markdown]
# Las activaciones no lineales son las que crean las asignaciones complejas entre las entradas y salidas del modelo. En éste caso, dado que Pytorch no posee activaciones tipo Seno, se crea una nueva subclase tipo módulo de Pytorch. Ésta activación se aplica después de transformaciones lineales para introducir la no linealidad. Se ha demostrado que esta elección de activación mejora el rendimiento de los PINN en la resolución de sistemas dinámicos no lineales y ecuaciones diferenciales parciales de alta dimensión (Norambuena et. al 2022).

# %%
#Definimos la clase Sin() que hereda de torch.nn.Module
class Sin(nn.Module):
    def __init__(self):
        super().__init__()
    def forward(self, input):
        return torch.sin(input)

# %% [markdown]
# ### Esqueleto de nuestra red neuronal:

# %% [markdown]
# La red neuronal consta de:
#
# 1. Una capa de entrada de valores de tiempo.
# 2. 4 capas ocultas, cada una de 200 neuronas.
# 3. En todas las neuronas de cada capa oculta se ejecutan operaciones lineales y seguido, se aplica la función de activación seno.
# 4. Una capa de salida que me arroja las funciones $N_i(t)$ de la parametrización.

# %% [markdown]
# <center>
# <img src="nn.png" width=800px>
# </center>

# %%
#En pytorch, todos los esqueletos de redes neuronales se definen como una clase que heredan los métodos y propiedades de torch.nn.Module
class NeuralNetwork(nn.Module):
    def __init__(self): 
        super().__init__()

        #A partir de aquí se definen las capas de mi red neuronal de forma ordenada:
        self.linear_sin_layers = nn.Sequential(
            #La primera capa es la capa de entrada y tiene len(t) elementos de entrada  --- CORREGIR
            #6 capas ocultas de 200 neuronas cada una, y la capa lineal de salida
            nn.Linear(1, 200),
            Sin(),
            nn.Linear(200, 200),
            Sin(),
            nn.Linear(200, 200),
            Sin(),
            nn.Linear(200, 200),
            Sin(),
            nn.Linear(200, 5),
        )  
    def forward(self, t):
        #Ésta instrucción asigna a la capa de entrada el vector de entrada "t"
        #Y propaga la salida de cada capa hacia la capa siguiente de forma sequencial
        outputs = self.linear_sin_layers(t)

        z1n = (outputs[:,0]).reshape(-1,1); 
        z2n = (outputs[:,1]).reshape(-1,1); 
        z3n = (outputs[:,2]).reshape(-1,1); 
        z4n = (outputs[:,3]).reshape(-1,1); 
        z5n = (outputs[:,4]).reshape(-1,1); 
        
        return z1n, z2n, z3n, z4n, z5n

# %% [markdown]
# ### Función del bucle de Entrenamiento

# %%
def train_neural_network(input_data, t_grid, modelo, optimizador, batch_number = 1):
    #Se crea un mini lote (en ésta red carece de sentido)
    t_batch, batch_start, batch_end, batch_size = crear_minibatch(t_grid, t_grid.shape[0], batch_number)

    #Definimos un contador de pérdida
    loss = 0
    Loss_history = []  

    #Se establece el modelo en modo entrenamiento, es decir: pytorch optimiza el proceso de entramiento internamente
    model.train()
    
    #Realizamos el entrenamiento por cada minibatch (mini lote) de valores de tiempo de tamaño: batch_size
    for batch in range(batch_number):
        #Toma todos los elementos del vector de tiempo que se encuentran desde el índice batch_start hasta batch_end
        t_mb = t_batch[batch_start:batch_end] 
        
        #Se evalúa la red neuronal con el mini lote de valores de tiempo 
        #Y se establecen las soluciones paramétricas de la ecuación maestra
        z1, z2, z3, z4, xi = parametric_solutions(t_mb, modelo, input_data)

        # Función de pérdida definida por las Ecs. de Hamilton (simplécticas): Escribiendo explícitamente las Ecs (más rápido)
        Ltot = hamEqs_Loss(t_mb,z1,z2,z3,z4,xi,input_data)

        l2_lambda = 0.001
        l2_reg = torch.tensor(0.)
        for param in modelo.parameters():
            l2_reg += torch.norm(param)
        Ltot += l2_lambda * l2_reg

        Ltot.backward(retain_graph=False); #True
        optimizador.step(); 
        loss += Ltot.data.numpy()
       
        optimizador.zero_grad()

        #Ahora tomamos los valores de tiempo del siguiente batch
        batch_start +=batch_size
        batch_end +=batch_size


        Loss_history.append(loss)       
    return Loss_history, modelo

# %% [markdown]
# ### Función del bucle de Prueba/Testeo

# %%
def test_neural_network(input_data, modelo, optimizador, epochs, t_size): 
    pass

# %% [markdown]
# ### Función para agregar perturbación estocástica al vector de tiempo

# %%
def perturbar_puntos_tiempo(t_0, t_max, t_size=300, sig=0.5):
    grid = torch.linspace(t_0, t_max, t_size).reshape(-1, 1)
    delta_t = grid[1] - grid[0]  
    noise = delta_t * torch.randn_like(grid)*sig
    t = grid + noise
    t.data[2] = torch.ones(1,1)*(-1)
    t.data[t<t_0]=t_0 - t.data[t<t_0]
    t.data[t>t_max]=2*t_max - t.data[t>t_max]
    t.data[0] = torch.ones(1,1)*t_0
    t.requires_grad = False
    return t

# %% [markdown]
# ### Función para crear lotes de datos

# %%
def crear_minibatch(t_grid, t_size, batch_number): 
    #Ésta función crea lotes de datos para optimizar el proceso de entrenamiento. No tiene sentido en redes PINN
    batch_size = int(t_size/batch_number)
    batch_start, batch_end = 0, batch_size

    idx = np.random.permutation(t_size)
    t_b = t_grid[idx]
    t_b = t_grid
    t_b.requires_grad = True
    return t_b, batch_start, batch_end, batch_size

# %% [markdown]
# ### Función para evaluar la red neuronal en el vector de tiempo t, y generar soluciones paramétricas

# %%
 def parametric_solutions(t, modelo, input_data):
    #Filtramos input_data para obtener solamente las condiciones iniciales de las variables en t=0
    t_0, z1_0, z2_0, z3_0, z4_0, xi_0 = input_data[:6]
    
    #Evaluamos nuestra red neuronal en el vector de tiempo t
    N_1, N_2, N_3, N_4, N_5 = modelo(t)

    #Obtenemos el diferencial entre el vector t y el valor t_0 (ocurre broadcasting)
    dt = t-t_0

    #Se define la función paramétrica, y a su vez, todas las soluciones paramétricas para cada componente del vector x(t) y u(t)
    f = (1-torch.exp(-dt))
    #La mejor función que afecte en menor medida el resultado de la red neuronal
     
    #Soluciones para x(t) (dinámica del sistema)
    Z1 = z1_0 + f*N_1
    Z2 = z2_0 + f*N_2
    Z3 = z3_0 + f*N_3
    Z4 = z4_0 + f*N_4

    #Soluciones para u(t) (función de control)
    Z5 = xi_0 + f*N_5
    
    
    return Z1, Z2, Z3, Z4, Z5

# %% [markdown]
# ### Función de pérdida definida por las Ecs. de Hamilton (simplécticas):

# %%
def hamEqs_Loss(t, z1, z2, z3, z4, xi, input_data):
    #gamma_abs 6
    #gamma_em 7
    #omegax 8
    #omegaz 9
    # Equations
    #f1 = df(z1,t) + input_data[6]*z1 - input_data[7]*z2 + 2*input_data[8]*z4
    #f2 = df(z2,t) -input_data[6]*z1 + input_data[7]*z2 - 2*input_data[8]*z4
    #f3 = df(z3,t) + input_data[6]*z3/2 + input_data[7]*z3/2 + input_data[9]*z4 + z4*(input_data[9] + xi)
    #f4 = df(z4,t) + input_data[6]*z4/2 + input_data[7]*z4/2 - input_data[8]*z1 + input_data[8]*z2 - input_data[9]*z3 - z3*(input_data[9] + xi)

    f1 = df(z1,t) + input_data[6]*z1 - gamma_em*z2 + 2*omega_x*z12_i
    f2 = df(z2,t) -input_data[6]*z1 + gamma_em*z2 - 2*omega_x*z12_i
    f3 = df(z12r,t) + input_data[6]*z12_r/2 + gamma_em*z12_r/2 + 2*omega_z*z12_i
    f4 = df(z12i,t) + input_data[6]*z12_i/2 + gamma_em*z12_i/2 - omega_x*z1 + omega_x*z2 - 2*omega_z*z12_r

    # Términos de pérdida del modelo
    L1 = (f1.pow(2)).mean();  #¿?
    L2 = (f2.pow(2)).mean(); 
    L3 = (f3.pow(2)).mean(); 
    L4 = (f4.pow(2)).mean(); 
    Lmodel = L1+L2+L3+L4; 

    # Límites para el control (Lcontrol)
    f5 = z1 - 1/2
    f6 = z2 - 1/2    # State Transfer Condition
    f7 = z1 + z2 - 1 # Tr(rho) = 1
    f8 = z3 - 1/2
    f9 = z4
    
    L5 = (f5.pow(2)).mean();  
    L6 = (f6.pow(2)).mean(); 
    L7 = (f7.pow(2)).mean(); 
    L8 = (f8.pow(2)).mean(); 
    L9 = (f9.pow(2)).mean(); 
           
    L = Lmodel + 1e-1*L5 + 1e-1*L6 + 1e-1*L7 
    #+ 1e-1*L8 + 1e-1*L9

    return L

def df(f,t):
    return grad([f], [t], grad_outputs=torch.ones(t.shape, dtype=dtype), create_graph=True)[0]

# %% [markdown]
# ## Ejecución del modelo: Entrenamiento y Prueba

# %%
#Se genera una instancia de nuestro modelo de red neuronal
model = NeuralNetwork()

#Hiperparámetros de la red neuronal
learning_rate = 1e-3
batch_number = 10 #Número de lotes de datos de entrada
epochs = 1000

#Se define la función de costo y el optimizador de la función de costo, en éste caso, se usa el optimizador: ADAM.
#loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

#Se define la configuración del vector discreto de tiempo
t_0 = 0 #Tiempo inicial
t_max = 20 #Tiempo final
t_size = 300 #Número de elementos del vector de tiempo

#Se define un vector columna de tiempo entre t_0 y t_max de 300 elementos y se agrega el efecto de una perturbación estocástica:
t_grid = perturbar_puntos_tiempo(t_0, t_max, t_size)


xi_0 = 0 #Función de control en t = 0
z1_0, z2_0, z3_0, z4_0 = [1, 0, 0, 0] #Componentes de la matriz densidad (específicamente del vector x(t)) evaluadas en t = 0
gamma_1, gamma_2 = [0.1, 0.3] #Tasas de disipación por absorción y emisión respectivamente
omega_x, omega_z = [1, 2] #Frecuencia de modulación

#Se definen las variables iniciales (t=0) de entrada (inputs) de nuestra red neuronal
input_data = [t_0, z1_0, z2_0, z3_0, z4_0, xi_0, gamma_1, gamma_2, omega_x, omega_z]

# %%
for epoch in range(epochs):
    #En cada época, el objeto "model" que representa la red, actualiza sus parámetros con base en los valores previos
    print(f"Época {epoch+1}\n-------------------------------")
    loss_history, model = train_neural_network(input_data, t_grid, model, optimizer, batch_number)
    print('Training Loss: ',  loss_history[-1] )

print("¡Proceso Finalizado!")
# Out:
# Época 1
# -------------------------------
# Training Loss:  12.289573788642883
# Época 2
# -------------------------------
# Training Loss:  68.00724884867668
# Época 3
# -------------------------------
# Training Loss:  88.7328851222992
# Época 4
# -------------------------------
# Training Loss:  95.77103373408318
# Época 5
# -------------------------------
# Training Loss:  231.58356627821922
# Época 6
# -------------------------------
# Training Loss:  172.63575148582458
# Época 7
# -------------------------------
# Training Loss:  183.1051890850067
# Época 8
# -------------------------------
# Training Loss:  26.026176750659943
# Época 9
# -------------------------------
# Training Loss:  5.7714327201247215
# Época 10
# -------------------------------
# Training Loss:  2.3366586714982986
# Época 11
# -------------------------------
# Training Loss:  1.3262593932449818
# Época 12
# -------------------------------
# Training Loss:  1.0937827341258526
# Época 13
# -------------------------------
# Training Loss:  0.9297557324171066
# Época 14
# -------------------------------
# Training Loss:  0.8336442559957504
# Época 15
# -------------------------------
# Training Loss:  0.7684795744717121
# Época 16
# -------------------------------
# Training Loss:  0.7336933389306068
# Época 17
# -------------------------------
# Training Loss:  0.7085606753826141
# Época 18
# -------------------------------
# Training Loss:  0.6890859417617321
# Época 19
# -------------------------------
# Training Loss:  0.6741157807409763
# Época 20
# -------------------------------
# Training Loss:  0.6609484069049358
# Época 21
# -------------------------------
# Training Loss:  0.6498235799372196
# Época 22
# -------------------------------
# Training Loss:  0.639829233288765
# Época 23
# -------------------------------
# Training Loss:  0.6310436986386776
# Época 24
# -------------------------------
# Training Loss:  0.6230941489338875
# Época 25
# -------------------------------
# Training Loss:  0.6159705370664597
# Época 26
# -------------------------------
# Training Loss:  0.6094749495387077
# Época 27
# -------------------------------
# Training Loss:  0.6035824678838253
# Época 28
# -------------------------------
# Training Loss:  0.5981964655220509
# Época 29
# -------------------------------
# Training Loss:  0.5932873077690601
# Época 30
# -------------------------------
# Training Loss:  0.5887887254357338
# Época 31
# -------------------------------
# Training Loss:  0.5846720561385155
# Época 32
# -------------------------------
# Training Loss:  0.5808906890451908
# Época 33
# -------------------------------
# Training Loss:  0.577418576925993
# Época 34
# -------------------------------
# Training Loss:  0.5742197744548321
# Época 35
# -------------------------------
# Training Loss:  0.5712720677256584
# Época 36
# -------------------------------
# Training Loss:  0.5685475580394268
# Época 37
# -------------------------------
# Training Loss:  0.5660274587571621
# Época 38
# -------------------------------
# Training Loss:  0.5636895522475243
# Época 39
# -------------------------------
# Training Loss:  0.5615182034671307
# Época 40
# -------------------------------
# Training Loss:  0.5594959743320942
# Época 41
# -------------------------------
# Training Loss:  0.557609785348177
# Época 42
# -------------------------------
# Training Loss:  0.5558458715677261
# Época 43
# -------------------------------
# Training Loss:  0.5541935786604881
# Época 44
# -------------------------------
# Training Loss:  0.5526420325040817
# Época 45
# -------------------------------
# Training Loss:  0.5511824265122414
# Época 46
# -------------------------------
# Training Loss:  0.5498063340783119
# Época 47
# -------------------------------
# Training Loss:  0.5485065169632435
# Época 48
# -------------------------------
# Training Loss:  0.5472762361168861
# Época 49
# -------------------------------
# Training Loss:  0.546109713613987
# Época 50
# -------------------------------
# Training Loss:  0.5450015589594841
# Época 51
# -------------------------------
# Training Loss:  0.5439470373094082
# Época 52
# -------------------------------
# Training Loss:  0.5429418049752712
# Época 53
# -------------------------------
# Training Loss:  0.5419820062816143
# Época 54
# -------------------------------
# Training Loss:  0.5410641580820084
# Época 55
# -------------------------------
# Training Loss:  0.54018509760499
# Época 56
# -------------------------------
# Training Loss:  0.5393418781459332
# Época 57
# -------------------------------
# Training Loss:  0.5385319478809834
# Época 58
# -------------------------------
# Training Loss:  0.5377528071403503
# Época 59
# -------------------------------
# Training Loss:  0.5370024032890797
# Época 60
# -------------------------------
# Training Loss:  0.5362786836922169
# Época 61
# -------------------------------
# Training Loss:  0.535579752177
# Época 62
# -------------------------------
# Training Loss:  0.5349039658904076
# Época 63
# -------------------------------
# Training Loss:  0.534249808639288
# Época 64
# -------------------------------
# Training Loss:  0.5336157865822315
# Época 65
# -------------------------------
# Training Loss:  0.533000648021698
# Época 66
# -------------------------------
# Training Loss:  0.5324030071496964
# Época 67
# -------------------------------
# Training Loss:  0.5318219624459743
# Época 68
# -------------------------------
# Training Loss:  0.531256303191185
# Época 69
# -------------------------------
# Training Loss:  0.5307050794363022
# Época 70
# -------------------------------
# Training Loss:  0.5301674380898476
# Época 71
# -------------------------------
# Training Loss:  0.5296424627304077
# Época 72
# -------------------------------
# Training Loss:  0.5291294530034065
# Época 73
# -------------------------------
# Training Loss:  0.5286276452243328
# Época 74
# -------------------------------
# Training Loss:  0.528136357665062
# Época 75
# -------------------------------
# Training Loss:  0.5276549682021141
# Época 76
# -------------------------------
# Training Loss:  0.5271828919649124
# Época 77
# -------------------------------
# Training Loss:  0.526719719171524
# Época 78
# -------------------------------
# Training Loss:  0.5262646824121475
# Época 79
# -------------------------------
# Training Loss:  0.5258176028728485
# Época 80
# -------------------------------
# Training Loss:  0.5253778137266636
# Época 81
# -------------------------------
# Training Loss:  0.5249450169503689
# Época 82
# -------------------------------
# Training Loss:  0.5245188660919666
# Época 83
# -------------------------------
# Training Loss:  0.5240990035235882
# Época 84
# -------------------------------
# Training Loss:  0.5236850492656231
# Época 85
# -------------------------------
# Training Loss:  0.5232767313718796
# Época 86
# -------------------------------
# Training Loss:  0.5228738337755203
# Época 87
# -------------------------------
# Training Loss:  0.5224760062992573
# Época 88
# -------------------------------
# Training Loss:  0.5220830403268337
# Época 89
# -------------------------------
# Training Loss:  0.5216948017477989
# Época 90
# -------------------------------
# Training Loss:  0.5213109664618969
# Época 91
# -------------------------------
# Training Loss:  0.5209313444793224
# Época 92
# -------------------------------
# Training Loss:  0.5205558314919472
# Época 93
# -------------------------------
# Training Loss:  0.5201842896640301
# Época 94
# -------------------------------
# Training Loss:  0.5198164694011211
# Época 95
# -------------------------------
# Training Loss:  0.5194521248340607
# Época 96
# -------------------------------
# Training Loss:  0.519091509282589
# Época 97
# -------------------------------
# Training Loss:  0.518734335899353
# Época 98
# -------------------------------
# Training Loss:  0.5183799974620342
# Época 99
# -------------------------------
# Training Loss:  0.5180287659168243
# Época 100
# -------------------------------
# Training Loss:  0.5176814757287502
# Época 101
# -------------------------------
# Training Loss:  0.5173372216522694
# Época 102
# -------------------------------
# Training Loss:  0.5169936791062355
# Época 103
# -------------------------------
# Training Loss:  0.5166542306542397
# Época 104
# -------------------------------
# Training Loss:  0.5163216330111027
# Época 105
# -------------------------------
# Training Loss:  0.5159921906888485
# Época 106
# -------------------------------
# Training Loss:  0.5156543664634228
# Época 107
# -------------------------------
# Training Loss:  0.5153439380228519
# Época 108
# -------------------------------
# Training Loss:  0.5150642432272434
# Época 109
# -------------------------------
# Training Loss:  0.5148535557091236
# Época 110
# -------------------------------
# Training Loss:  0.5146836899220943
# Época 111
# -------------------------------
# Training Loss:  0.5151477716863155
# Época 112
# -------------------------------
# Training Loss:  0.5168423689901829
# Época 113
# -------------------------------
# Training Loss:  0.5220374539494514
# Época 114
# -------------------------------
# Training Loss:  0.5380360968410969
# Época 115
# -------------------------------
# Training Loss:  0.5813107937574387
# Época 116
# -------------------------------
# Training Loss:  0.7308642491698265
# Época 117
# -------------------------------
# Training Loss:  1.076269630342722
# Época 118
# -------------------------------
# Training Loss:  2.550858210772276
# Época 119
# -------------------------------
# Training Loss:  3.175363417714834
# Época 120
# -------------------------------
# Training Loss:  8.11775854229927
# Época 121
# -------------------------------
# Training Loss:  4.635079771280289
# Época 122
# -------------------------------
# Training Loss:  1.0676669850945473
# Época 123
# -------------------------------
# Training Loss:  0.7981264479458332
# Época 124
# -------------------------------
# Training Loss:  0.6365188658237457
# Época 125
# -------------------------------
# Training Loss:  0.598811462521553
# Época 126
# -------------------------------
# Training Loss:  0.5610297061502934
# Época 127
# -------------------------------
# Training Loss:  0.5545443668961525
# Época 128
# -------------------------------
# Training Loss:  0.5445452593266964
# Época 129
# -------------------------------
# Training Loss:  0.5407307632267475
# Época 130
# -------------------------------
# Training Loss:  0.5380941554903984
# Época 131
# -------------------------------
# Training Loss:  0.5363400541245937
# Época 132
# -------------------------------
# Training Loss:  0.5347546376287937
# Época 133
# -------------------------------
# Training Loss:  0.5333886370062828
# Época 134
# -------------------------------
# Training Loss:  0.5321183428168297
# Época 135
# -------------------------------
# Training Loss:  0.530932355672121
# Época 136
# -------------------------------
# Training Loss:  0.5298126488924026
# Época 137
# -------------------------------
# Training Loss:  0.5287430435419083
# Época 138
# -------------------------------
# Training Loss:  0.5277238972485065
# Época 139
# -------------------------------
# Training Loss:  0.5267478637397289
# Época 140
# -------------------------------
# Training Loss:  0.5258128382265568
# Época 141
# -------------------------------
# Training Loss:  0.5249142050743103
# Época 142
# -------------------------------
# Training Loss:  0.5240489579737186
# Época 143
# -------------------------------
# Training Loss:  0.5232142619788647
# Época 144
# -------------------------------
# Training Loss:  0.5224076993763447
# Época 145
# -------------------------------
# Training Loss:  0.5216273106634617
# Época 146
# -------------------------------
# Training Loss:  0.5208712369203568
# Época 147
# -------------------------------
# Training Loss:  0.5201379470527172
# Época 148
# -------------------------------
# Training Loss:  0.5194259770214558
# Época 149
# -------------------------------
# Training Loss:  0.5187340788543224
# Época 150
# -------------------------------
# Training Loss:  0.5180610567331314
# Época 151
# -------------------------------
# Training Loss:  0.5174059271812439
# Época 152
# -------------------------------
# Training Loss:  0.5167677327990532
# Época 153
# -------------------------------
# Training Loss:  0.5161457099020481
# Época 154
# -------------------------------
# Training Loss:  0.515539076179266
# Época 155
# -------------------------------
# Training Loss:  0.5149471014738083
# Época 156
# -------------------------------
# Training Loss:  0.5143691711127758
# Época 157
# -------------------------------
# Training Loss:  0.5138047114014626
# Época 158
# -------------------------------
# Training Loss:  0.5132531970739365
# Época 159
# -------------------------------
# Training Loss:  0.5127141363918781
# Época 160
# -------------------------------
# Training Loss:  0.5121869705617428
# Época 161
# -------------------------------
# Training Loss:  0.5116713903844357
# Época 162
# -------------------------------
# Training Loss:  0.5111669190227985
# Época 163
# -------------------------------
# Training Loss:  0.5106732733547688
# Época 164
# -------------------------------
# Training Loss:  0.5101899839937687
# Época 165
# -------------------------------
# Training Loss:  0.5097168311476707
# Época 166
# -------------------------------
# Training Loss:  0.50925337895751
# Época 167
# -------------------------------
# Training Loss:  0.5087994188070297
# Época 168
# -------------------------------
# Training Loss:  0.508354626595974
# Época 169
# -------------------------------
# Training Loss:  0.5079187527298927
# Época 170
# -------------------------------
# Training Loss:  0.5074914917349815
# Época 171
# -------------------------------
# Training Loss:  0.5070726498961449
# Época 172
# -------------------------------
# Training Loss:  0.5066619850695133
# Época 173
# -------------------------------
# Training Loss:  0.5062591917812824
# Época 174
# -------------------------------
# Training Loss:  0.505864106118679
# Época 175
# -------------------------------
# Training Loss:  0.5054764524102211
# Época 176
# -------------------------------
# Training Loss:  0.5050960518419743
# Época 177
# -------------------------------
# Training Loss:  0.5047227293252945
# Época 178
# -------------------------------
# Training Loss:  0.5043562650680542
# Época 179
# -------------------------------
# Training Loss:  0.5039964243769646
# Época 180
# -------------------------------
# Training Loss:  0.5036430060863495
# Época 181
# -------------------------------
# Training Loss:  0.5032958649098873
# Época 182
# -------------------------------
# Training Loss:  0.502954863011837
# Época 183
# -------------------------------
# Training Loss:  0.5026196949183941
# Época 184
# -------------------------------
# Training Loss:  0.5022902488708496
# Época 185
# -------------------------------
# Training Loss:  0.5019663497805595
# Época 186
# -------------------------------
# Training Loss:  0.501647837460041
# Época 187
# -------------------------------
# Training Loss:  0.5013345219194889
# Época 188
# -------------------------------
# Training Loss:  0.5010263249278069
# Época 189
# -------------------------------
# Training Loss:  0.5007229074835777
# Época 190
# -------------------------------
# Training Loss:  0.5004243142902851
# Época 191
# -------------------------------
# Training Loss:  0.5001302175223827
# Época 192
# -------------------------------
# Training Loss:  0.4998405799269676
# Época 193
# -------------------------------
# Training Loss:  0.49955523759126663
# Época 194
# -------------------------------
# Training Loss:  0.49927404150366783
# Época 195
# -------------------------------
# Training Loss:  0.4989968501031399
# Época 196
# -------------------------------
# Training Loss:  0.49872349202632904
# Época 197
# -------------------------------
# Training Loss:  0.49845384806394577
# Época 198
# -------------------------------
# Training Loss:  0.4981878101825714
# Época 199
# -------------------------------
# Training Loss:  0.4979252330958843
# Época 200
# -------------------------------
# Training Loss:  0.49766605347394943
# Época 201
# -------------------------------
# Training Loss:  0.49741003289818764
# Época 202
# -------------------------------
# Training Loss:  0.49715716764330864
# Época 203
# -------------------------------
# Training Loss:  0.49690724164247513
# Época 204
# -------------------------------
# Training Loss:  0.4966602548956871
# Época 205
# -------------------------------
# Training Loss:  0.49641599133610725
# Época 206
# -------------------------------
# Training Loss:  0.4961743988096714
# Época 207
# -------------------------------
# Training Loss:  0.49593543261289597
# Época 208
# -------------------------------
# Training Loss:  0.49569883942604065
# Época 209
# -------------------------------
# Training Loss:  0.49546463787555695
# Época 210
# -------------------------------
# Training Loss:  0.495232705026865
# Época 211
# -------------------------------
# Training Loss:  0.49500295519828796
# Época 212
# -------------------------------
# Training Loss:  0.49477532505989075
# Época 213
# -------------------------------
# Training Loss:  0.4945497028529644
# Época 214
# -------------------------------
# Training Loss:  0.49432599917054176
# Época 215
# -------------------------------
# Training Loss:  0.49410412460565567
# Época 216
# -------------------------------
# Training Loss:  0.49388400465250015
# Época 217
# -------------------------------
# Training Loss:  0.4936656281352043
# Época 218
# -------------------------------
# Training Loss:  0.4934488870203495
# Época 219
# -------------------------------
# Training Loss:  0.4932336360216141
# Época 220
# -------------------------------
# Training Loss:  0.4930199012160301
# Época 221
# -------------------------------
# Training Loss:  0.4928075671195984
# Época 222
# -------------------------------
# Training Loss:  0.4925965741276741
# Época 223
# -------------------------------
# Training Loss:  0.49238694831728935
# Época 224
# -------------------------------
# Training Loss:  0.4921784959733486
# Época 225
# -------------------------------
# Training Loss:  0.49197129160165787
# Época 226
# -------------------------------
# Training Loss:  0.491765134036541
# Época 227
# -------------------------------
# Training Loss:  0.4915601424872875
# Época 228
# -------------------------------
# Training Loss:  0.49135614559054375
# Época 229
# -------------------------------
# Training Loss:  0.49115315824747086
# Época 230
# -------------------------------
# Training Loss:  0.4909510314464569
# Época 231
# -------------------------------
# Training Loss:  0.4907498210668564
# Época 232
# -------------------------------
# Training Loss:  0.4905494563281536
# Época 233
# -------------------------------
# Training Loss:  0.4903498999774456
# Época 234
# -------------------------------
# Training Loss:  0.4901510700583458
# Época 235
# -------------------------------
# Training Loss:  0.48995303735136986
# Época 236
# -------------------------------
# Training Loss:  0.48975563049316406
# Época 237
# -------------------------------
# Training Loss:  0.4895588718354702
# Época 238
# -------------------------------
# Training Loss:  0.4893626980483532
# Época 239
# -------------------------------
# Training Loss:  0.48916716128587723
# Época 240
# -------------------------------
# Training Loss:  0.48897214978933334
# Época 241
# -------------------------------
# Training Loss:  0.48877761885523796
# Época 242
# -------------------------------
# Training Loss:  0.48858361318707466
# Época 243
# -------------------------------
# Training Loss:  0.4883900210261345
# Época 244
# -------------------------------
# Training Loss:  0.48819687590003014
# Época 245
# -------------------------------
# Training Loss:  0.4880041405558586
# Época 246
# -------------------------------
# Training Loss:  0.48781175538897514
# Época 247
# -------------------------------
# Training Loss:  0.48761967942118645
# Época 248
# -------------------------------
# Training Loss:  0.4874279983341694
# Época 249
# -------------------------------
# Training Loss:  0.487236563116312
# Época 250
# -------------------------------
# Training Loss:  0.48704535886645317
# Época 251
# -------------------------------
# Training Loss:  0.4868544712662697
# Época 252
# -------------------------------
# Training Loss:  0.4866638518869877
# Época 253
# -------------------------------
# Training Loss:  0.48647333309054375
# Época 254
# -------------------------------
# Training Loss:  0.48628294467926025
# Época 255
# -------------------------------
# Training Loss:  0.48609283939003944
# Época 256
# -------------------------------
# Training Loss:  0.48590293526649475
# Época 257
# -------------------------------
# Training Loss:  0.4857129417359829
# Época 258
# -------------------------------
# Training Loss:  0.485523022711277
# Época 259
# -------------------------------
# Training Loss:  0.48533353209495544
# Época 260
# -------------------------------
# Training Loss:  0.4851440414786339
# Época 261
# -------------------------------
# Training Loss:  0.484954085201025
# Época 262
# -------------------------------
# Training Loss:  0.48476434871554375
# Época 263
# -------------------------------
# Training Loss:  0.4845753684639931
# Época 264
# -------------------------------
# Training Loss:  0.4843861199915409
# Época 265
# -------------------------------
# Training Loss:  0.4841955490410328
# Época 266
# -------------------------------
# Training Loss:  0.4840059280395508
# Época 267
# -------------------------------
# Training Loss:  0.48381776735186577
# Época 268
# -------------------------------
# Training Loss:  0.4836292266845703
# Época 269
# -------------------------------
# Training Loss:  0.48343751952052116
# Época 270
# -------------------------------
# Training Loss:  0.48324835300445557
# Época 271
# -------------------------------
# Training Loss:  0.4830622747540474
# Época 272
# -------------------------------
# Training Loss:  0.48288438469171524
# Época 273
# -------------------------------
# Training Loss:  0.4826931618154049
# Época 274
# -------------------------------
# Training Loss:  0.48252663761377335
# Época 275
# -------------------------------
# Training Loss:  0.4823751598596573
# Época 276
# -------------------------------
# Training Loss:  0.4823928326368332
# Época 277
# -------------------------------
# Training Loss:  0.4824765846133232
# Época 278
# -------------------------------
# Training Loss:  0.4832478202879429
# Época 279
# -------------------------------
# Training Loss:  0.48520011827349663
# Época 280
# -------------------------------
# Training Loss:  0.4915587715804577
# Época 281
# -------------------------------
# Training Loss:  0.5039885826408863
# Época 282
# -------------------------------
# Training Loss:  0.542280163615942
# Época 283
# -------------------------------
# Training Loss:  0.6051046065986156
# Época 284
# -------------------------------
# Training Loss:  0.8069616630673409
# Época 285
# -------------------------------
# Training Loss:  0.9745959788560867
# Época 286
# -------------------------------
# Training Loss:  1.666387751698494
# Época 287
# -------------------------------
# Training Loss:  1.9351118952035904
# Época 288
# -------------------------------
# Training Loss:  1.7326424568891525
# Época 289
# -------------------------------
# Training Loss:  2.4052717983722687
# Época 290
# -------------------------------
# Training Loss:  1.0135515704751015
# Época 291
# -------------------------------
# Training Loss:  1.614566758275032
# Época 292
# -------------------------------
# Training Loss:  1.423335187137127
# Época 293
# -------------------------------
# Training Loss:  0.9521501958370209
# Época 294
# -------------------------------
# Training Loss:  0.6475729458034039
# Época 295
# -------------------------------
# Training Loss:  0.5567852929234505
# Época 296
# -------------------------------
# Training Loss:  0.5428788289427757
# Época 297
# -------------------------------
# Training Loss:  0.528771661221981
# Época 298
# -------------------------------
# Training Loss:  0.5261085815727711
# Época 299
# -------------------------------
# Training Loss:  0.5205461233854294
# Época 300
# -------------------------------
# Training Loss:  0.5180298909544945
# Época 301
# -------------------------------
# Training Loss:  0.5151070579886436
# Época 302
# -------------------------------
# Training Loss:  0.5129513181746006
# Época 303
# -------------------------------
# Training Loss:  0.5108748078346252
# Época 304
# -------------------------------
# Training Loss:  0.5089357942342758
# Época 305
# -------------------------------
# Training Loss:  0.5071404874324799
# Época 306
# -------------------------------
# Training Loss:  0.5054308250546455
# Época 307
# -------------------------------
# Training Loss:  0.5038341283798218
# Época 308
# -------------------------------
# Training Loss:  0.502326026558876
# Época 309
# -------------------------------
# Training Loss:  0.5009087808430195
# Época 310
# -------------------------------
# Training Loss:  0.4995746314525604
# Época 311
# -------------------------------
# Training Loss:  0.4983208030462265
# Época 312
# -------------------------------
# Training Loss:  0.4971403069794178
# Época 313
# -------------------------------
# Training Loss:  0.49602727219462395
# Época 314
# -------------------------------
# Training Loss:  0.4949772246181965
# Época 315
# -------------------------------
# Training Loss:  0.49398451298475266
# Época 316
# -------------------------------
# Training Loss:  0.49304455146193504
# Época 317
# -------------------------------
# Training Loss:  0.49215342476963997
# Época 318
# -------------------------------
# Training Loss:  0.49130726605653763
# Época 319
# -------------------------------
# Training Loss:  0.4905029721558094
# Época 320
# -------------------------------
# Training Loss:  0.48973775655031204
# Época 321
# -------------------------------
# Training Loss:  0.489009078592062
# Época 322
# -------------------------------
# Training Loss:  0.48831459879875183
# Época 323
# -------------------------------
# Training Loss:  0.4876522608101368
# Época 324
# -------------------------------
# Training Loss:  0.4870200529694557
# Época 325
# -------------------------------
# Training Loss:  0.4864160977303982
# Época 326
# -------------------------------
# Training Loss:  0.4858386144042015
# Época 327
# -------------------------------
# Training Loss:  0.4852859154343605
# Época 328
# -------------------------------
# Training Loss:  0.48475638031959534
# Época 329
# -------------------------------
# Training Loss:  0.4842485338449478
# Época 330
# -------------------------------
# Training Loss:  0.48376085981726646
# Época 331
# -------------------------------
# Training Loss:  0.48329197242856026
# Época 332
# -------------------------------
# Training Loss:  0.48284053057432175
# Época 333
# -------------------------------
# Training Loss:  0.4824053533375263
# Época 334
# -------------------------------
# Training Loss:  0.4819851592183113
# Época 335
# -------------------------------
# Training Loss:  0.48157890141010284
# Época 336
# -------------------------------
# Training Loss:  0.481185395270586
# Época 337
# -------------------------------
# Training Loss:  0.4808037541806698
# Época 338
# -------------------------------
# Training Loss:  0.4804329574108124
# Época 339
# -------------------------------
# Training Loss:  0.48007216677069664
# Época 340
# -------------------------------
# Training Loss:  0.4797205217182636
# Época 341
# -------------------------------
# Training Loss:  0.47937721386551857
# Época 342
# -------------------------------
# Training Loss:  0.47904157266020775
# Época 343
# -------------------------------
# Training Loss:  0.47871284931898117
# Época 344
# -------------------------------
# Training Loss:  0.47839047759771347
# Época 345
# -------------------------------
# Training Loss:  0.4780738726258278
# Época 346
# -------------------------------
# Training Loss:  0.47776246443390846
# Época 347
# -------------------------------
# Training Loss:  0.4774557240307331
# Época 348
# -------------------------------
# Training Loss:  0.47715334594249725
# Época 349
# -------------------------------
# Training Loss:  0.4768548384308815
# Época 350
# -------------------------------
# Training Loss:  0.4765595868229866
# Época 351
# -------------------------------
# Training Loss:  0.4762674532830715
# Época 352
# -------------------------------
# Training Loss:  0.47597841545939445
# Época 353
# -------------------------------
# Training Loss:  0.4756917469203472
# Época 354
# -------------------------------
# Training Loss:  0.4754067286849022
# Época 355
# -------------------------------
# Training Loss:  0.47512422874569893
# Época 356
# -------------------------------
# Training Loss:  0.4748445674777031
# Época 357
# -------------------------------
# Training Loss:  0.4745647832751274
# Época 358
# -------------------------------
# Training Loss:  0.4742852710187435
# Época 359
# -------------------------------
# Training Loss:  0.4740109443664551
# Época 360
# -------------------------------
# Training Loss:  0.4737462066113949
# Época 361
# -------------------------------
# Training Loss:  0.4734630286693573
# Época 362
# -------------------------------
# Training Loss:  0.4732261747121811
# Época 363
# -------------------------------
# Training Loss:  0.4729885384440422
# Época 364
# -------------------------------
# Training Loss:  0.4730645641684532
# Época 365
# -------------------------------
# Training Loss:  0.4730660878121853
# Época 366
# -------------------------------
# Training Loss:  0.4750540964305401
# Época 367
# -------------------------------
# Training Loss:  0.48111390694975853
# Época 368
# -------------------------------
# Training Loss:  0.4952012337744236
# Época 369
# -------------------------------
# Training Loss:  0.5832299590110779
# Época 370
# -------------------------------
# Training Loss:  0.6559036709368229
# Época 371
# -------------------------------
# Training Loss:  1.656451255083084
# Época 372
# -------------------------------
# Training Loss:  1.4923910573124886
# Época 373
# -------------------------------
# Training Loss:  3.9605787694454193
# Época 374
# -------------------------------
# Training Loss:  1.2605892047286034
# Época 375
# -------------------------------
# Training Loss:  1.0105670504271984
# Época 376
# -------------------------------
# Training Loss:  0.8902648873627186
# Época 377
# -------------------------------
# Training Loss:  0.9407456293702126
# Época 378
# -------------------------------
# Training Loss:  0.6262435615062714
# Época 379
# -------------------------------
# Training Loss:  0.6248713098466396
# Época 380
# -------------------------------
# Training Loss:  0.5841703936457634
# Época 381
# -------------------------------
# Training Loss:  0.5445419028401375
# Época 382
# -------------------------------
# Training Loss:  0.5307318717241287
# Época 383
# -------------------------------
# Training Loss:  0.5256384052336216
# Época 384
# -------------------------------
# Training Loss:  0.519982136785984
# Época 385
# -------------------------------
# Training Loss:  0.5162458680570126
# Época 386
# -------------------------------
# Training Loss:  0.5127440504729748
# Época 387
# -------------------------------
# Training Loss:  0.5096209347248077
# Época 388
# -------------------------------
# Training Loss:  0.507032010704279
# Época 389
# -------------------------------
# Training Loss:  0.5045585632324219
# Época 390
# -------------------------------
# Training Loss:  0.5023368746042252
# Época 391
# -------------------------------
# Training Loss:  0.5003062412142754
# Época 392
# -------------------------------
# Training Loss:  0.4984572306275368
# Época 393
# -------------------------------
# Training Loss:  0.49671001359820366
# Época 394
# -------------------------------
# Training Loss:  0.4951271153986454
# Época 395
# -------------------------------
# Training Loss:  0.49365225061774254
# Época 396
# -------------------------------
# Training Loss:  0.49228544905781746
# Época 397
# -------------------------------
# Training Loss:  0.491003155708313
# Época 398
# -------------------------------
# Training Loss:  0.4898141250014305
# Época 399
# -------------------------------
# Training Loss:  0.4887012243270874
# Época 400
# -------------------------------
# Training Loss:  0.487656619399786
# Época 401
# -------------------------------
# Training Loss:  0.48667213320732117
# Época 402
# -------------------------------
# Training Loss:  0.4857465401291847
# Época 403
# -------------------------------
# Training Loss:  0.4848731532692909
# Época 404
# -------------------------------
# Training Loss:  0.48404450342059135
# Época 405
# -------------------------------
# Training Loss:  0.48325633257627487
# Época 406
# -------------------------------
# Training Loss:  0.48250725120306015
# Época 407
# -------------------------------
# Training Loss:  0.4817938096821308
# Época 408
# -------------------------------
# Training Loss:  0.48111002147197723
# Época 409
# -------------------------------
# Training Loss:  0.48045235872268677
# Época 410
# -------------------------------
# Training Loss:  0.4798211008310318
# Época 411
# -------------------------------
# Training Loss:  0.4792150668799877
# Época 412
# -------------------------------
# Training Loss:  0.4786285124719143
# Época 413
# -------------------------------
# Training Loss:  0.4780573546886444
# Época 414
# -------------------------------
# Training Loss:  0.47750432789325714
# Época 415
# -------------------------------
# Training Loss:  0.4769712872803211
# Época 416
# -------------------------------
# Training Loss:  0.47645146772265434
# Época 417
# -------------------------------
# Training Loss:  0.4759370796382427
# Época 418
# -------------------------------
# Training Loss:  0.47543488815426826
# Época 419
# -------------------------------
# Training Loss:  0.4749538227915764
# Época 420
# -------------------------------
# Training Loss:  0.47448524460196495
# Época 421
# -------------------------------
# Training Loss:  0.47400767356157303
# Época 422
# -------------------------------
# Training Loss:  0.47353631630539894
# Época 423
# -------------------------------
# Training Loss:  0.47309815138578415
# Época 424
# -------------------------------
# Training Loss:  0.4726940281689167
# Época 425
# -------------------------------
# Training Loss:  0.472248587757349
# Época 426
# -------------------------------
# Training Loss:  0.47181104123592377
# Época 427
# -------------------------------
# Training Loss:  0.47144703567028046
# Época 428
# -------------------------------
# Training Loss:  0.4712822251021862
# Época 429
# -------------------------------
# Training Loss:  0.471064280718565
# Época 430
# -------------------------------
# Training Loss:  0.47100500017404556
# Época 431
# -------------------------------
# Training Loss:  0.47152451798319817
# Época 432
# -------------------------------
# Training Loss:  0.4731866642832756
# Época 433
# -------------------------------
# Training Loss:  0.47754794359207153
# Época 434
# -------------------------------
# Training Loss:  0.48204556107521057
# Época 435
# -------------------------------
# Training Loss:  0.5018600709736347
# Época 436
# -------------------------------
# Training Loss:  0.5177250988781452
# Época 437
# -------------------------------
# Training Loss:  0.5953069664537907
# Época 438
# -------------------------------
# Training Loss:  0.620745837688446
# Época 439
# -------------------------------
# Training Loss:  0.8222385719418526
# Época 440
# -------------------------------
# Training Loss:  0.7487075366079807
# Época 441
# -------------------------------
# Training Loss:  0.8186972662806511
# Época 442
# -------------------------------
# Training Loss:  0.802788931876421
# Época 443
# -------------------------------
# Training Loss:  0.7328150793910027
# Época 444
# -------------------------------
# Training Loss:  0.7033940739929676
# Época 445
# -------------------------------
# Training Loss:  0.64134681224823
# Época 446
# -------------------------------
# Training Loss:  0.6841919682919979
# Época 447
# -------------------------------
# Training Loss:  0.8198218420147896
# Época 448
# -------------------------------
# Training Loss:  0.8277823626995087
# Época 449
# -------------------------------
# Training Loss:  0.7288255989551544
# Época 450
# -------------------------------
# Training Loss:  0.8441361486911774
# Época 451
# -------------------------------
# Training Loss:  0.8726344332098961
# Época 452
# -------------------------------
# Training Loss:  1.117646187543869
# Época 453
# -------------------------------
# Training Loss:  0.6231209747493267
# Época 454
# -------------------------------
# Training Loss:  0.6332450322806835
# Época 455
# -------------------------------
# Training Loss:  0.5517694093286991
# Época 456
# -------------------------------
# Training Loss:  0.5359840951859951
# Época 457
# -------------------------------
# Training Loss:  0.49764667451381683
# Época 458
# -------------------------------
# Training Loss:  0.49267156049609184
# Época 459
# -------------------------------
# Training Loss:  0.4832962267100811
# Época 460
# -------------------------------
# Training Loss:  0.48055629432201385
# Época 461
# -------------------------------
# Training Loss:  0.4778400883078575
# Época 462
# -------------------------------
# Training Loss:  0.4760233461856842
# Época 463
# -------------------------------
# Training Loss:  0.4744919538497925
# Época 464
# -------------------------------
# Training Loss:  0.4728277213871479
# Época 465
# -------------------------------
# Training Loss:  0.47151436284184456
# Época 466
# -------------------------------
# Training Loss:  0.47031134366989136
# Época 467
# -------------------------------
# Training Loss:  0.46912406384944916
# Época 468
# -------------------------------
# Training Loss:  0.46805182844400406
# Época 469
# -------------------------------
# Training Loss:  0.4670579917728901
# Época 470
# -------------------------------
# Training Loss:  0.46610835939645767
# Época 471
# -------------------------------
# Training Loss:  0.4652152992784977
# Época 472
# -------------------------------
# Training Loss:  0.46437394991517067
# Época 473
# -------------------------------
# Training Loss:  0.46357322484254837
# Época 474
# -------------------------------
# Training Loss:  0.46281013637781143
# Época 475
# -------------------------------
# Training Loss:  0.4620826542377472
# Época 476
# -------------------------------
# Training Loss:  0.4613872542977333
# Época 477
# -------------------------------
# Training Loss:  0.46072064712643623
# Época 478
# -------------------------------
# Training Loss:  0.4600803144276142
# Época 479
# -------------------------------
# Training Loss:  0.4594643898308277
# Época 480
# -------------------------------
# Training Loss:  0.45887109637260437
# Época 481
# -------------------------------
# Training Loss:  0.45829834416508675
# Época 482
# -------------------------------
# Training Loss:  0.4577443450689316
# Época 483
# -------------------------------
# Training Loss:  0.457208052277565
# Época 484
# -------------------------------
# Training Loss:  0.4566883109509945
# Época 485
# -------------------------------
# Training Loss:  0.4561835899949074
# Época 486
# -------------------------------
# Training Loss:  0.455692533403635
# Época 487
# -------------------------------
# Training Loss:  0.4552146941423416
# Época 488
# -------------------------------
# Training Loss:  0.45474934205412865
# Época 489
# -------------------------------
# Training Loss:  0.4542950950562954
# Época 490
# -------------------------------
# Training Loss:  0.45385078340768814
# Época 491
# -------------------------------
# Training Loss:  0.45341678336262703
# Época 492
# -------------------------------
# Training Loss:  0.4529926925897598
# Época 493
# -------------------------------
# Training Loss:  0.4525764435529709
# Época 494
# -------------------------------
# Training Loss:  0.45216716825962067
# Época 495
# -------------------------------
# Training Loss:  0.4517667517066002
# Época 496
# -------------------------------
# Training Loss:  0.4513756111264229
# Época 497
# -------------------------------
# Training Loss:  0.4509879909455776
# Época 498
# -------------------------------
# Training Loss:  0.45060447230935097
# Época 499
# -------------------------------
# Training Loss:  0.4502321630716324
# Época 500
# -------------------------------
# Training Loss:  0.44987692683935165
# Época 501
# -------------------------------
# Training Loss:  0.44950706139206886
# Época 502
# -------------------------------
# Training Loss:  0.44916219264268875
# Época 503
# -------------------------------
# Training Loss:  0.4488321468234062
# Época 504
# -------------------------------
# Training Loss:  0.44873008131980896
# Época 505
# -------------------------------
# Training Loss:  0.44842400401830673
# Época 506
# -------------------------------
# Training Loss:  0.4494413956999779
# Época 507
# -------------------------------
# Training Loss:  0.45032577589154243
# Época 508
# -------------------------------
# Training Loss:  0.46164023876190186
# Época 509
# -------------------------------
# Training Loss:  0.4719846211373806
# Época 510
# -------------------------------
# Training Loss:  0.5652105696499348
# Época 511
# -------------------------------
# Training Loss:  0.6751480139791965
# Época 512
# -------------------------------
# Training Loss:  1.153652336448431
# Época 513
# -------------------------------
# Training Loss:  1.2384106405079365
# Época 514
# -------------------------------
# Training Loss:  1.3768453374505043
# Época 515
# -------------------------------
# Training Loss:  0.9066348150372505
# Época 516
# -------------------------------
# Training Loss:  0.8774837143719196
# Época 517
# -------------------------------
# Training Loss:  0.6992151513695717
# Época 518
# -------------------------------
# Training Loss:  0.5847232975065708
# Época 519
# -------------------------------
# Training Loss:  0.5252363607287407
# Época 520
# -------------------------------
# Training Loss:  0.512031689286232
# Época 521
# -------------------------------
# Training Loss:  0.4878268875181675
# Época 522
# -------------------------------
# Training Loss:  0.4727843776345253
# Época 523
# -------------------------------
# Training Loss:  0.467323899269104
# Época 524
# -------------------------------
# Training Loss:  0.4657464139163494
# Época 525
# -------------------------------
# Training Loss:  0.4636012203991413
# Época 526
# -------------------------------
# Training Loss:  0.46241743862628937
# Época 527
# -------------------------------
# Training Loss:  0.461420189589262
# Época 528
# -------------------------------
# Training Loss:  0.4603048041462898
# Época 529
# -------------------------------
# Training Loss:  0.4594124145805836
# Época 530
# -------------------------------
# Training Loss:  0.4585774876177311
# Época 531
# -------------------------------
# Training Loss:  0.45771943777799606
# Época 532
# -------------------------------
# Training Loss:  0.456939984112978
# Época 533
# -------------------------------
# Training Loss:  0.45621464401483536
# Época 534
# -------------------------------
# Training Loss:  0.4555012360215187
# Época 535
# -------------------------------
# Training Loss:  0.4548078440129757
# Época 536
# -------------------------------
# Training Loss:  0.4541524462401867
# Época 537
# -------------------------------
# Training Loss:  0.45352188497781754
# Época 538
# -------------------------------
# Training Loss:  0.4528997056186199
# Época 539
# -------------------------------
# Training Loss:  0.45229581743478775
# Época 540
# -------------------------------
# Training Loss:  0.45171747729182243
# Época 541
# -------------------------------
# Training Loss:  0.45115139335393906
# Época 542
# -------------------------------
# Training Loss:  0.45059091225266457
# Época 543
# -------------------------------
# Training Loss:  0.45004719123244286
# Época 544
# -------------------------------
# Training Loss:  0.44952236115932465
# Época 545
# -------------------------------
# Training Loss:  0.44900302961468697
# Época 546
# -------------------------------
# Training Loss:  0.44848665222525597
# Época 547
# -------------------------------
# Training Loss:  0.44798751547932625
# Época 548
# -------------------------------
# Training Loss:  0.44750411808490753
# Época 549
# -------------------------------
# Training Loss:  0.4470205120742321
# Época 550
# -------------------------------
# Training Loss:  0.4465358331799507
# Época 551
# -------------------------------
# Training Loss:  0.44607407227158546
# Época 552
# -------------------------------
# Training Loss:  0.4456300884485245
# Época 553
# -------------------------------
# Training Loss:  0.44517382234334946
# Época 554
# -------------------------------
# Training Loss:  0.44471657648682594
# Época 555
# -------------------------------
# Training Loss:  0.4442942887544632
# Época 556
# -------------------------------
# Training Loss:  0.44393427670001984
# Época 557
# -------------------------------
# Training Loss:  0.4434894621372223
# Época 558
# -------------------------------
# Training Loss:  0.4431733898818493
# Época 559
# -------------------------------
# Training Loss:  0.442823201417923
# Época 560
# -------------------------------
# Training Loss:  0.44313613697886467
# Época 561
# -------------------------------
# Training Loss:  0.44274697452783585
# Época 562
# -------------------------------
# Training Loss:  0.444589089602232
# Época 563
# -------------------------------
# Training Loss:  0.44551605358719826
# Época 564
# -------------------------------
# Training Loss:  0.4552893042564392
# Época 565
# -------------------------------
# Training Loss:  0.462924774736166
# Época 566
# -------------------------------
# Training Loss:  0.4961487166583538
# Época 567
# -------------------------------
# Training Loss:  0.5397632159292698
# Época 568
# -------------------------------
# Training Loss:  0.616198655217886
# Época 569
# -------------------------------
# Training Loss:  0.7636551484465599
# Época 570
# -------------------------------
# Training Loss:  0.6352878995239735
# Época 571
# -------------------------------
# Training Loss:  0.630482904613018
# Época 572
# -------------------------------
# Training Loss:  0.5089381821453571
# Época 573
# -------------------------------
# Training Loss:  0.47761501371860504
# Época 574
# -------------------------------
# Training Loss:  0.4565340653061867
# Época 575
# -------------------------------
# Training Loss:  0.44824017956852913
# Época 576
# -------------------------------
# Training Loss:  0.4493308886885643
# Época 577
# -------------------------------
# Training Loss:  0.44713638350367546
# Época 578
# -------------------------------
# Training Loss:  0.44791071861982346
# Época 579
# -------------------------------
# Training Loss:  0.4462357200682163
# Época 580
# -------------------------------
# Training Loss:  0.44565075635910034
# Época 581
# -------------------------------
# Training Loss:  0.4465937949717045
# Época 582
# -------------------------------
# Training Loss:  0.44837546721100807
# Época 583
# -------------------------------
# Training Loss:  0.44959545135498047
# Época 584
# -------------------------------
# Training Loss:  0.4534166604280472
# Época 585
# -------------------------------
# Training Loss:  0.4568695202469826
# Época 586
# -------------------------------
# Training Loss:  0.46764059737324715
# Época 587
# -------------------------------
# Training Loss:  0.4742650166153908
# Época 588
# -------------------------------
# Training Loss:  0.4832044132053852
# Época 589
# -------------------------------
# Training Loss:  0.5004525184631348
# Época 590
# -------------------------------
# Training Loss:  0.5027439333498478
# Época 591
# -------------------------------
# Training Loss:  0.5243499353528023
# Época 592
# -------------------------------
# Training Loss:  0.4920603223145008
# Época 593
# -------------------------------
# Training Loss:  0.4906286224722862
# Época 594
# -------------------------------
# Training Loss:  0.4788324199616909
# Época 595
# -------------------------------
# Training Loss:  0.47387926653027534
# Época 596
# -------------------------------
# Training Loss:  0.4572986997663975
# Época 597
# -------------------------------
# Training Loss:  0.44837963953614235
# Época 598
# -------------------------------
# Training Loss:  0.4439391680061817
# Época 599
# -------------------------------
# Training Loss:  0.44273219257593155
# Época 600
# -------------------------------
# Training Loss:  0.4410061426460743
# Época 601
# -------------------------------
# Training Loss:  0.4388263188302517
# Época 602
# -------------------------------
# Training Loss:  0.43708986788988113
# Época 603
# -------------------------------
# Training Loss:  0.4369918294250965
# Época 604
# -------------------------------
# Training Loss:  0.4367245100438595
# Época 605
# -------------------------------
# Training Loss:  0.4360715188086033
# Época 606
# -------------------------------
# Training Loss:  0.435502327978611
# Época 607
# -------------------------------
# Training Loss:  0.43515413254499435
# Época 608
# -------------------------------
# Training Loss:  0.43617599084973335
# Época 609
# -------------------------------
# Training Loss:  0.43564528226852417
# Época 610
# -------------------------------
# Training Loss:  0.438125167042017
# Época 611
# -------------------------------
# Training Loss:  0.436312660574913
# Época 612
# -------------------------------
# Training Loss:  0.44287923723459244
# Época 613
# -------------------------------
# Training Loss:  0.43935779482126236
# Época 614
# -------------------------------
# Training Loss:  0.45335179939866066
# Época 615
# -------------------------------
# Training Loss:  0.4484803304076195
# Época 616
# -------------------------------
# Training Loss:  0.4662335626780987
# Época 617
# -------------------------------
# Training Loss:  0.45972195640206337
# Época 618
# -------------------------------
# Training Loss:  0.4792453423142433
# Época 619
# -------------------------------
# Training Loss:  0.4816618598997593
# Época 620
# -------------------------------
# Training Loss:  0.4745999798178673
# Época 621
# -------------------------------
# Training Loss:  0.4797673486173153
# Época 622
# -------------------------------
# Training Loss:  0.45572322234511375
# Época 623
# -------------------------------
# Training Loss:  0.46488360315561295
# Época 624
# -------------------------------
# ...
# -------------------------------
# Training Loss:  0.6197000294923782
# Época 794
# -------------------------------
# Training Loss:  0.6185450702905655
# Época 795
# -------------------------------
# Training Loss:  0.6174138635396957
# Época 796
# -------------------------------
# Training Loss:  0.6163051389157772
# Época 797
# -------------------------------
# Training Loss:  0.6152178570628166
# Época 798
# -------------------------------
# Training Loss:  0.6141509674489498
# Época 799
# -------------------------------
# Training Loss:  0.6131035648286343
# Época 800
# -------------------------------
# Training Loss:  0.6120748296380043
# Época 801
# -------------------------------
# Training Loss:  0.6110640168190002
# Época 802
# -------------------------------
# Training Loss:  0.6100705452263355
# Época 803
# -------------------------------
# Training Loss:  0.6090936250984669
# Época 804
# -------------------------------
# Training Loss:  0.6081328988075256
# Época 805
# -------------------------------
# Training Loss:  0.6071879267692566
# Época 806
# -------------------------------
# Training Loss:  0.6062580645084381
# Época 807
# -------------------------------
# Training Loss:  0.6053430140018463
# Época 808
# -------------------------------
# Training Loss:  0.6044425070285797
# Época 809
# -------------------------------
# Training Loss:  0.6035560443997383
# Época 810
# -------------------------------
# Training Loss:  0.6026834510266781
# Época 811
# -------------------------------
# Training Loss:  0.601824689656496
# Época 812
# -------------------------------
# Training Loss:  0.6009787619113922
# Época 813
# -------------------------------
# Training Loss:  0.6001464016735554
# Época 814
# -------------------------------
# Training Loss:  0.5993270576000214
# Época 815
# -------------------------------
# Training Loss:  0.5985196009278297
# Época 816
# -------------------------------
# Training Loss:  0.5977255403995514
# Época 817
# -------------------------------
# Training Loss:  0.596944160759449
# Época 818
# -------------------------------
# Training Loss:  0.5961727499961853
# Época 819
# -------------------------------
# Training Loss:  0.5954164117574692
# Época 820
# -------------------------------
# Training Loss:  0.5946720875799656
# Época 821
# -------------------------------
# Training Loss:  0.5939334817230701
# Época 822
# -------------------------------
# Training Loss:  0.5932165086269379
# Época 823
# -------------------------------
# Training Loss:  0.5925103984773159
# Época 824
# -------------------------------
# Training Loss:  0.5917997471988201
# Época 825
# -------------------------------
# Training Loss:  0.5911367572844028
# Época 826
# -------------------------------
# Training Loss:  0.5904918350279331
# Época 827
# -------------------------------
# Training Loss:  0.5898552425205708
# Época 828
# -------------------------------
# Training Loss:  0.5893976464867592
# Época 829
# -------------------------------
# Training Loss:  0.5892150104045868
# Época 830
# -------------------------------
# Training Loss:  0.5902168788015842
# Época 831
# -------------------------------
# Training Loss:  0.5929313935339451
# Época 832
# -------------------------------
# Training Loss:  0.601712055504322
# Época 833
# -------------------------------
# Training Loss:  0.6462003290653229
# Época 834
# -------------------------------
# Training Loss:  0.7332029677927494
# Época 835
# -------------------------------
# Training Loss:  0.9439573287963867
# Época 836
# -------------------------------
# Training Loss:  1.9668988846242428
# Época 837
# -------------------------------
# Training Loss:  3.0350195840001106
# Época 838
# -------------------------------
# Training Loss:  3.7585545629262924
# Época 839
# -------------------------------
# Training Loss:  5.525026805698872
# Época 840
# -------------------------------
# Training Loss:  3.7345127761363983
# Época 841
# -------------------------------
# Training Loss:  2.2675587832927704
# Época 842
# -------------------------------
# Training Loss:  1.5581730753183365
# Época 843
# -------------------------------
# Training Loss:  1.3795319944620132
# Época 844
# -------------------------------
# Training Loss:  1.1689914166927338
# Época 845
# -------------------------------
# Training Loss:  0.877270296216011
# Época 846
# -------------------------------
# Training Loss:  0.6712376475334167
# Época 847
# -------------------------------
# Training Loss:  0.6548662707209587
# Época 848
# -------------------------------
# Training Loss:  0.6405530534684658
# Época 849
# -------------------------------
# Training Loss:  0.6363031417131424
# Época 850
# -------------------------------
# Training Loss:  0.6298150159418583
# Época 851
# -------------------------------
# Training Loss:  0.626739151775837
# Época 852
# -------------------------------
# Training Loss:  0.6234090887010098
# Época 853
# -------------------------------
# Training Loss:  0.6210094764828682
# Época 854
# -------------------------------
# Training Loss:  0.6187011003494263
# Época 855
# -------------------------------
# Training Loss:  0.6166421547532082
# Época 856
# -------------------------------
# Training Loss:  0.6147269420325756
# Época 857
# -------------------------------
# Training Loss:  0.6129071563482285
# Época 858
# -------------------------------
# Training Loss:  0.6112141720950603
# Época 859
# -------------------------------
# Training Loss:  0.6095979325473309
# Época 860
# -------------------------------
# Training Loss:  0.6080663949251175
# Época 861
# -------------------------------
# Training Loss:  0.6066006794571877
# Época 862
# -------------------------------
# Training Loss:  0.6051984764635563
# Época 863
# -------------------------------
# Training Loss:  0.6038537435233593
# Época 864
# -------------------------------
# Training Loss:  0.6025596782565117
# Época 865
# -------------------------------
# Training Loss:  0.6013148799538612
# Época 866
# -------------------------------
# Training Loss:  0.6001138612627983
# Época 867
# -------------------------------
# Training Loss:  0.5989548712968826
# Época 868
# -------------------------------
# Training Loss:  0.5978347174823284
# Época 869
# -------------------------------
# Training Loss:  0.5967512801289558
# Época 870
# -------------------------------
# Training Loss:  0.5957024693489075
# Época 871
# -------------------------------
# Training Loss:  0.5946864821016788
# Época 872
# -------------------------------
# Training Loss:  0.5937014631927013
# Época 873
# -------------------------------
# Training Loss:  0.5927459672093391
# Época 874
# -------------------------------
# Training Loss:  0.5918185971677303
# Época 875
# -------------------------------
# Training Loss:  0.5909180156886578
# Época 876
# -------------------------------
# Training Loss:  0.5900429710745811
# Época 877
# -------------------------------
# Training Loss:  0.5891924947500229
# Época 878
# -------------------------------
# Training Loss:  0.5883652754127979
# Época 879
# -------------------------------
# Training Loss:  0.587560635060072
# Época 880
# -------------------------------
# Training Loss:  0.5867774970829487
# Época 881
# -------------------------------
# Training Loss:  0.5860150754451752
# Época 882
# -------------------------------
# Training Loss:  0.5852725580334663
# Época 883
# -------------------------------
# Training Loss:  0.5845492109656334
# Época 884
# -------------------------------
# Training Loss:  0.5838443152606487
# Época 885
# -------------------------------
# Training Loss:  0.5831572487950325
# Época 886
# -------------------------------
# Training Loss:  0.5824874117970467
# Época 887
# -------------------------------
# Training Loss:  0.5818341039121151
# Época 888
# -------------------------------
# Training Loss:  0.5811968334019184
# Época 889
# -------------------------------
# Training Loss:  0.5805751904845238
# Época 890
# -------------------------------
# Training Loss:  0.5799685306847095
# Época 891
# -------------------------------
# Training Loss:  0.579376358538866
# Época 892
# -------------------------------
# Training Loss:  0.5787983983755112
# Época 893
# -------------------------------
# Training Loss:  0.5782340690493584
# Época 894
# -------------------------------
# Training Loss:  0.5776829533278942
# Época 895
# -------------------------------
# Training Loss:  0.5771447271108627
# Época 896
# -------------------------------
# Training Loss:  0.5766190253198147
# Época 897
# -------------------------------
# Training Loss:  0.5761054493486881
# Época 898
# -------------------------------
# Training Loss:  0.5756037272512913
# Época 899
# -------------------------------
# Training Loss:  0.5751133561134338
# Época 900
# -------------------------------
# Training Loss:  0.5746341161429882
# Época 901
# -------------------------------
# Training Loss:  0.5741657726466656
# Época 902
# -------------------------------
# Training Loss:  0.5737078301608562
# Época 903
# -------------------------------
# Training Loss:  0.5732602030038834
# Época 904
# -------------------------------
# Training Loss:  0.5728225782513618
# Época 905
# -------------------------------
# Training Loss:  0.572394609451294
# Época 906
# -------------------------------
# Training Loss:  0.5719759725034237
# Época 907
# -------------------------------
# Training Loss:  0.57156677916646
# Época 908
# -------------------------------
# Training Loss:  0.5711663626134396
# Época 909
# -------------------------------
# Training Loss:  0.5707743763923645
# Época 910
# -------------------------------
# Training Loss:  0.5703915692865849
# Época 911
# -------------------------------
# Training Loss:  0.5700168125331402
# Época 912
# -------------------------------
# Training Loss:  0.5696489550173283
# Época 913
# -------------------------------
# Training Loss:  0.5692909881472588
# Época 914
# -------------------------------
# Training Loss:  0.5689408406615257
# Época 915
# -------------------------------
# Training Loss:  0.5685938037931919
# Época 916
# -------------------------------
# Training Loss:  0.5682606287300587
# Época 917
# -------------------------------
# Training Loss:  0.5679415725171566
# Época 918
# -------------------------------
# Training Loss:  0.5676146261394024
# Época 919
# -------------------------------
# Training Loss:  0.5673176199197769
# Época 920
# -------------------------------
# Training Loss:  0.5671590194106102
# Época 921
# -------------------------------
# Training Loss:  0.5670047849416733
# Época 922
# -------------------------------
# Training Loss:  0.5670519061386585
# Época 923
# -------------------------------
# Training Loss:  0.570231556892395
# Época 924
# -------------------------------
# Training Loss:  0.5744463838636875
# Época 925
# -------------------------------
# Training Loss:  0.587081640958786
# Época 926
# -------------------------------
# Training Loss:  0.6894834376871586
# Época 927
# -------------------------------
# Training Loss:  0.7968874759972095
# Época 928
# -------------------------------
# Training Loss:  1.3220372311770916
# Época 929
# -------------------------------
# Training Loss:  3.1145941093564034
# Época 930
# -------------------------------
# Training Loss:  2.413737542927265
# Época 931
# -------------------------------
# Training Loss:  3.4852932691574097
# Época 932
# -------------------------------
# Training Loss:  2.8018351197242737
# Época 933
# -------------------------------
# Training Loss:  2.224867932498455
# Época 934
# -------------------------------
# Training Loss:  1.7722648903727531
# Época 935
# -------------------------------
# Training Loss:  1.2320588454604149
# Época 936
# -------------------------------
# Training Loss:  0.8832794800400734
# Época 937
# -------------------------------
# Training Loss:  0.7369032204151154
# Época 938
# -------------------------------
# Training Loss:  0.668050728738308
# Época 939
# -------------------------------
# Training Loss:  0.6339865997433662
# Época 940
# -------------------------------
# Training Loss:  0.6181674040853977
# Época 941
# -------------------------------
# Training Loss:  0.6086847372353077
# Época 942
# -------------------------------
# Training Loss:  0.6047573238611221
# Época 943
# -------------------------------
# Training Loss:  0.6005502976477146
# Época 944
# -------------------------------
# Training Loss:  0.597636591643095
# Época 945
# -------------------------------
# Training Loss:  0.5950264669954777
# Época 946
# -------------------------------
# Training Loss:  0.5927633680403233
# Época 947
# -------------------------------
# Training Loss:  0.5907377786934376
# Época 948
# -------------------------------
# Training Loss:  0.588892936706543
# Época 949
# -------------------------------
# Training Loss:  0.587216854095459
# Época 950
# -------------------------------
# Training Loss:  0.5856544896960258
# Época 951
# -------------------------------
# Training Loss:  0.5842187069356441
# Época 952
# -------------------------------
# Training Loss:  0.5828710868954659
# Época 953
# -------------------------------
# Training Loss:  0.5816133804619312
# Época 954
# -------------------------------
# Training Loss:  0.5804308876395226
# Época 955
# -------------------------------
# Training Loss:  0.5793159753084183
# Época 956
# -------------------------------
# Training Loss:  0.5782633796334267
# Época 957
# -------------------------------
# Training Loss:  0.5772661082446575
# Época 958
# -------------------------------
# Training Loss:  0.5763200931251049
# Época 959
# -------------------------------
# Training Loss:  0.575420718640089
# Época 960
# -------------------------------
# Training Loss:  0.5745643265545368
# Época 961
# -------------------------------
# Training Loss:  0.5737477131187916
# Época 962
# -------------------------------
# Training Loss:  0.5729678496718407
# Época 963
# -------------------------------
# Training Loss:  0.5722221434116364
# Época 964
# -------------------------------
# Training Loss:  0.5715082213282585
# Época 965
# -------------------------------
# Training Loss:  0.570823960006237
# Época 966
# -------------------------------
# Training Loss:  0.570167500525713
# Época 967
# -------------------------------
# Training Loss:  0.5695370696485043
# Época 968
# -------------------------------
# Training Loss:  0.5689310990273952
# Época 969
# -------------------------------
# Training Loss:  0.568348053842783
# Época 970
# -------------------------------
# Training Loss:  0.5677867569029331
# Época 971
# -------------------------------
# Training Loss:  0.5672459676861763
# Época 972
# -------------------------------
# Training Loss:  0.5667245276272297
# Época 973
# -------------------------------
# Training Loss:  0.5662215203046799
# Época 974
# -------------------------------
# Training Loss:  0.5657359398901463
# Época 975
# -------------------------------
# Training Loss:  0.565266914665699
# Época 976
# -------------------------------
# Training Loss:  0.564813744276762
# Época 977
# -------------------------------
# Training Loss:  0.564375638961792
# Época 978
# -------------------------------
# Training Loss:  0.563951876014471
# Época 979
# -------------------------------
# Training Loss:  0.5635418184101582
# Época 980
# -------------------------------
# Training Loss:  0.5631448403000832
# Época 981
# -------------------------------
# Training Loss:  0.562760453671217
# Época 982
# -------------------------------
# Training Loss:  0.5623880922794342
# Época 983
# -------------------------------
# Training Loss:  0.5620272606611252
# Época 984
# -------------------------------
# Training Loss:  0.5616775117814541
# Época 985
# -------------------------------
# Training Loss:  0.5613382756710052
# Época 986
# -------------------------------
# Training Loss:  0.5610092617571354
# Época 987
# -------------------------------
# Training Loss:  0.5606900304555893
# Época 988
# -------------------------------
# Training Loss:  0.5603801906108856
# Época 989
# -------------------------------
# Training Loss:  0.5600793175399303
# Época 990
# -------------------------------
# Training Loss:  0.5597871467471123
# Época 991
# -------------------------------
# Training Loss:  0.559503361582756
# Época 992
# -------------------------------
# Training Loss:  0.5592275112867355
# Época 993
# -------------------------------
# Training Loss:  0.5589594058692455
# Época 994
# -------------------------------
# Training Loss:  0.5586988031864166
# Época 995
# -------------------------------
# Training Loss:  0.5584452375769615
# Época 996
# -------------------------------
# Training Loss:  0.5581985041499138
# Época 997
# -------------------------------
# Training Loss:  0.5579585544764996
# Época 998
# -------------------------------
# Training Loss:  0.5577248558402061
# Época 999
# -------------------------------
# Training Loss:  0.5574969500303268
# Época 1000
# -------------------------------
# Training Loss:  0.5572757869958878
# ¡Proceso Finalizado!

# %%
# %matplotlib inline

#nTest = N ; t_max_test = 1.0*tmax
#tTest = torch.linspace(t0,t_max_test,nTest)
t_test = torch.linspace(t_0, t_max, t_size).reshape(-1, 1)
    
tTest = t_test.reshape(-1,1);
#tTest.requires_grad=True
t_net = tTest.detach().numpy()

z1,z2,z3,z4,xi = parametric_solutions(tTest,model,input_data)
z1=z1.data.numpy(); 
z2=z2.data.numpy()
z3=z3.data.numpy(); 
z4=z4.data.numpy(); 
xi=xi.data.numpy()


# Plot vector components
plt.figure(figsize=(5,4), tight_layout=True)
plt.plot(t_net, z1,'-b', linewidth=2, label=r'$\rho_{11}$'); 
plt.plot(t_net, z2,'-r', linewidth=2, label=r'$\rho_{22}$'); 
plt.xlim([0,10])
axes = plt.gca()
plt.xlabel('t')
axes.xaxis.label.set_size(14)
axes.yaxis.label.set_size(14)
plt.legend(prop={"size":10})
plt.grid()

# Plot vector components
plt.figure(figsize=(5,4), tight_layout=True)
plt.plot(t_net, z3,'-g', linewidth=2, label=r'$Re(\rho_{12})$'); 
plt.plot(t_net, z4,'-c', linewidth=2, label=r'$Im(\rho_{12})$'); 
axes = plt.gca()
plt.xlabel('t')
axes.xaxis.label.set_size(14)
axes.yaxis.label.set_size(14)
plt.legend(prop={"size":10})
plt.grid()


# Plot control functions
lineW = 2 # Line thickness
plt.figure(figsize=(5,4), tight_layout=True)
plt.plot(t_net, xi,'-b', linewidth=2, label=r'$\xi(t)$'); 
axes = plt.gca()
plt.xlabel('t')
axes.xaxis.label.set_size(14)
axes.yaxis.label.set_size(14)
plt.legend(prop={"size":10})
plt.grid()

# %% [markdown]
# ## Tarea:
# - Manipulación del estado objetivo
# - Qutip: solución del sistema de dos niveles sin el término de control

# %%
print("Hello")
# Out:
# Hello
